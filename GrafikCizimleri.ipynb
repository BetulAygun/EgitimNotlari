# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn.preprocessing
import sklearn.impute as impute
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier, 
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier, RandomForestRegressor
from sklearn.

# %%
x = np.arange(2001, 2021)
x
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %%
y = np.round(np.random.random(20) * 100, 2)
y
# Out:
# array([ 0.49, 48.28, 41.76,  8.34, 72.61, 83.  , 21.94, 77.28, 20.86,
#        15.62, 92.2 , 23.88, 34.83, 14.06, 12.67,  3.27, 15.53, 46.9 ,
#        53.45, 87.32])

# %%
y1 = np.round(np.random.random(20) * 100, 2)
y1
# Out:
# array([47.47,  1.47,  7.74, 80.11, 70.82, 85.42,  7.17, 77.56, 88.8 ,
#        46.38, 88.23, 85.54, 20.7 , 84.4 , 89.  , 14.05, 75.94, 98.63,
#        32.16, 54.53])

# %%
plt.plot(x, y, 'b-+')
plt.title("Yıllara Göre Büyüme Oranı")
plt.xlabel("Yıllar")
plt.ylabel("Büyüme Oranları")
plt.ylim(0,130)
plt.xticks([2000,2005,2010,2015,2020])
plt.yticks([0,50,100])
plt.legend(["Türkiye", "Bulgaristan"], loc = 'upper left')
plt.fill_between(x,y, alpha = 0.3)

# %%
plt.plot(x, y1, 'r--')
plt.title("Yıllara Göre Büyüme Oranı")
plt.xlabel("Yıllar")
plt.ylabel("Büyüme Oranları")
plt.ylim(0,130)
plt.xticks([2000,2005,2010,2015,2020])
plt.yticks([0,50,100])
plt.legend(["Türkiye", "Bulgaristan"], loc = 'upper left')
plt.fill_between(x,y1, alpha = 0.3)

# %%
plt.subplot(2,1,1)
plt.plot(x, y, 'b-+')
plt.title("Yıllara Göre Büyüme Oranı")
plt.xlabel("Yıllar")
plt.ylabel("Büyüme Oranları")
plt.ylim(0,130)
plt.xticks([2000,2005,2010,2015,2020])
plt.yticks([0,50,100])
plt.legend(["Türkiye", "Bulgaristan"], loc = 'upper left')
plt.fill_between(x,y, alpha = 0.3)

plt.subplot(2,1,2)
plt.plot(x, y1, 'r--')
plt.title("Yıllara Göre Büyüme Oranı")
plt.xlabel("Yıllar")
plt.ylabel("Büyüme Oranları")
plt.ylim(0,130)
plt.xticks([2000,2005,2010,2015,2020])
plt.yticks([0,50,100])
plt.legend(["Türkiye", "Bulgaristan"], loc = 'upper left')
plt.fill_between(x,y1, alpha = 0.3)

# %%
plt.axes([0.05,0.05, 0.8,1.2])
plt.plot(x, y, 'b-+')
plt.title("Yıllara Göre Büyüme Oranı")
plt.xlabel("Yıllar")
plt.ylabel("Büyüme Oranları")
plt.ylim(0,130)
plt.xticks([2000,2005,2010,2015,2020])
plt.yticks([0,50,100])
plt.legend(["Türkiye", "Bulgaristan"], loc = 'upper left')
plt.fill_between(x,y, alpha = 0.3)

plt.axes([0.55, 0.8, 0.2, 0.4])
plt.plot(x, y1, 'r--')
#plt.title("Yıllara Göre Büyüme Oranı")
plt.xlabel("Yıllar")
plt.ylabel("Büyüme Oranları")
plt.ylim(0,130)
plt.xticks([2001,2010,2020])
plt.yticks([0,50,100])
plt.legend(["Türkiye", "Bulgaristan"], loc = 'upper left')
plt.fill_between(x,y1, alpha = 0.3)

# %%
nba = pd.read_csv("nba.csv")
nba.head()
# Out:
#             Name            Team  Number Position  Age  Height  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     235
# 2   John Holland  Boston Celtics      30       SG   27     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
plt.plot(nba["Height"], "r:", label = "Height")
plt.plot(nba["Age"], "b-", label = "Age")
plt.plot(nba["Salary"], "g--", label = "Salary")
plt.yticks([40000,1500000, 10000000, 25000000])
plt.legend()

# %%
nba["Salary"].max()
# Out:
# 25000000.0

# %%
plt.plot(nba["Age"], nba["Height"], "r:")

# %%
nba['Age'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
nba[["Age","Height"]].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
sns.set()

# %%
plt.axes([0.05,0.05, 0.8,1.2])
plt.plot(x, y, 'b-+')
plt.title("Yıllara Göre Büyüme Oranı")
plt.xlabel("Yıllar")
plt.ylabel("Büyüme Oranları")
plt.ylim(0,130)
plt.xticks([2000,2005,2010,2015,2020])
plt.yticks([0,50,100])
plt.legend(["Türkiye", "Bulgaristan"], loc = 'upper left')
plt.fill_between(x,y, alpha = 0.3)

plt.axes([0.55, 0.8, 0.2, 0.4])
plt.plot(x, y1, 'r--')
#plt.title("Yıllara Göre Büyüme Oranı")
plt.xlabel("Yıllar")
plt.ylabel("Büyüme Oranları")
plt.ylim(0,130)
plt.xticks([2001,2010,2020])
plt.yticks([0,50,100])
plt.legend(["Türkiye", "Bulgaristan"], loc = 'upper left')
plt.fill_between(x,y1, alpha = 0.3)

# %%
sns.kdeplot(nba["Age"], nba["Height"], cbar = True)
# Out:
# C:\Users\Betul\PycharmProjects\EgitimNotlari\venv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Height'>

# %%
#sns.kdeplot(x = iris["sepal_length"], y = iris["petal_length"],  hue=iris["species"])
sns.kdeplot(x="sepal_length", y="petal_length",   data = iris, hue = "species")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
maske_setosa = iris["species"] == "setosa"
df_setosa = iris.loc[maske_setosa]
maske_versicolor = iris["species"] == "versicolor"
df_versicolor = iris.loc[maske_versicolor]

sns.kdeplot(df_setosa["sepal_length"], df_setosa["petal_length"])
sns.kdeplot(df_versicolor["sepal_length"], df_versicolor["petal_length"])
# Out:
# C:\Users\Betul\PycharmProjects\EgitimNotlari\venv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Betul\PycharmProjects\EgitimNotlari\venv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.pairplot(iris, hue="species")

# %%
np.corrcoef(iris["sepal_width"], iris["sepal_length"])
# Out:
# array([[ 1.        , -0.11756978],
#        [-0.11756978,  1.        ]])

# %%
iris_numeric = iris.iloc[:, 0:4]
iris_numeric
sns.distplot(iris_numeric["sepal_length"], bins= 10)
# Out:
# C:\Users\Betul\PycharmProjects\EgitimNotlari\venv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.jointplot(x = "sepal_length", y = "sepal_width", data = iris, kind = "kde", hue = "species")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
nba
# Out:
#               Name            Team  Number Position  Age  Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     235
# 2     John Holland  Boston Celtics      30       SG   27     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     231
# ..             ...             ...     ...      ...  ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26     203
# 454      Raul Neto       Utah Jazz      25       PG   24     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     256
# 456    Jeff Withey       Utah Jazz      24        C   26     231
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# ...

# %%
sns.pairplot(nba, hue="Position")

# %%
bitcoin = pd.read_csv(r"C:\Users\Betul\Desktop\BitcoinPrediction\BitCoinForecasting\bitcoindata_scaled_02.10.21.csv", sep=";")

# %%
bitcoin["Date"] = pd.to_datetime(bitcoin["Date"])

# %%
bitcoin.set_index(keys="Date", inplace=True)

# %%
bitcoin.sort_index()
# Out:
#              Bitcoin    EURUSD     SP500  DawJones       VIX      Gold  \
# Date
# 2013-04-29 -0.776521  1.384636 -1.597847 -1.564768 -0.419169  0.658277
# 2013-04-30 -0.777542  1.441948 -1.590240 -1.555560 -0.444735  0.659523
# 2013-05-01 -0.781600  1.519845 -1.618806 -1.606306 -0.314213  0.643321
# 2013-05-02 -0.783772  1.534783 -1.590201 -1.580267 -0.435316  0.576020
# 2013-05-03 -0.785147  1.408823 -1.557869 -1.541336 -0.534889  0.678218
# ...              ...       ...       ...       ...       ...       ...
# 2021-01-17  5.795220  0.366433  2.609253  2.197885  0.937182  2.493267
# 2021-01-18  5.949859  0.336624  2.623978  2.199161  0.900178  2.460198
# 2021-01-19  5.846569  0.346497  2.638703  2.200437  0.863174  2.505813
# 2021-01-20  5.750324  0.412725  2.740405  2.281478  0.639807  2.563143
# 2021-01-21  4.879779  0.387731  2.742748  2.236146  0.604822  2.628201
#
#              Libor3m    US10YR  WTICRUDE
# Date
# 2013-04-29 -0.887240 -0.695392  1.546898
# ...

# %%
sns.pairplot(bitcoin[["Bitcoin","SP500","DawJones"]])
