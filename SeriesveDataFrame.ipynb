# %%
#numpy -- Matematiksel işlemler
#Seriler ve DataFrameler - veri tipleri
import pandas as pd
import numpy as np

# %%
veri_pokemon = pd.read_csv(r"C:\Users\Betul\Desktop\VeriMadenciligi\pokemon.csv", usecols=["Name", "Attack"], 
                           index_col= ["Name"],  squeeze=True)

# %%
type(veri_pokemon)
veri_pokemon
# Out:
# Name
# Bulbasaur                 49
# Ivysaur                   62
# Venusaur                  82
# VenusaurMega Venusaur    100
# Charmander                52
#                         ...
# Diancie                  100
# DiancieMega Diancie      160
# HoopaHoopa Confined      110
# HoopaHoopa Unbound       160
# Volcanion                110
# Name: Attack, Length: 800, dtype: int64

# %%
veri_pokemon = veri_pokemon.sort_values(ascending=False)

# %%
medyan = veri_pokemon.median()
ortalama = veri_pokemon.mean()
toplam = veri_pokemon.sum()

# %%
mod = veri_pokemon.mode()
veri_pokemon.idxmin()
veri_pokemon['Chansey']
# Out:
# 5

# %%
yeni_veri = veri_pokemon[:100]

# %%
yeni_veri.to_csv("deneme.csv")

# %%
pokemon_Turler.value_counts(ascending = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4788/2844375953.py in <module>
# ----> 1 pokemon_Turler.value_counts(ascending = True)
#
# NameError: name 'pokemon_Turler' is not defined

# %%
veri_pokemon.head(2)
# Out:
# Name
# MewtwoMega Mewtwo X        190
# HeracrossMega Heracross    185
# Name: Attack, dtype: int64

# %%
def kategoriklestirme(atak):
    if atak < 100:
        return "Az Güçlü"
    else:
        return "Güçlü"

# %%
veri_pokemon = veri_pokemon.apply(kategoriklestirme)

# %%
veri_pokemon["MewtwoMega Mewtwo X"] = "Güçsüz"

# %%
veri_pokemon = pd.read_csv(r"C:\Users\Betul\Desktop\VeriMadenciligi\pokemon.csv", usecols=["Name", "Speed"], 
                           index_col= ["Name"],  squeeze=True)

# %%
veri_pokemon.max()
# Out:
# 180

# %%
veri_pokemon
# Out:
# Name
# Bulbasaur                 45
# Ivysaur                   60
# Venusaur                  80
# VenusaurMega Venusaur     80
# Charmander                65
#                         ...
# Diancie                   50
# DiancieMega Diancie      110
# HoopaHoopa Confined       70
# HoopaHoopa Unbound        80
# Volcanion                 70
# Name: Speed, Length: 800, dtype: int64

# %%
def sınıflandırma(hız):
    sonuc=""
    if hız < 50:
        sonuc="Az Hızlı"
    elif hız < 100:
        sonuc = "Hızlı"
    elif hız < 150:
        sonuc = "Çok Hızlı"
    elif hız < 200:
        sonuc = "Super Hızlı"
    else:
        sonuc = "Aykırı Bir değer"
        
    return sonuc

# %%
veri_pokemon.apply(sınıflandırma)
# Out:
# Name
# Bulbasaur                 Az Hızlı
# Ivysaur                      Hızlı
# Venusaur                     Hızlı
# VenusaurMega Venusaur        Hızlı
# Charmander                   Hızlı
#                            ...
# Diancie                      Hızlı
# DiancieMega Diancie      Çok Hızlı
# HoopaHoopa Confined          Hızlı
# HoopaHoopa Unbound           Hızlı
# Volcanion                    Hızlı
# Name: Speed, Length: 800, dtype: object

# %% [markdown]
# # Data Frame

# %%
nba = pd.read_csv("nba.csv")

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age  Height  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     235
# 2   John Holland  Boston Celtics      30       SG   27     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=457, step=1)

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'College',
#        'Salary'],
#       dtype='object')

# %%
nba.describe()
# Out:
#            Number         Age      Height        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int64
#  5   Height    457 non-null    int64
#  6   College   373 non-null    object
#  7   Salary    446 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 28.7+ KB

# %%
nba.sum()
# Out:
# C:\Users\Betul\AppData\Local\Temp/ipykernel_4788/1629379923.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   nba.sum()
# Name        Avery BradleyJae CrowderJohn HollandR.J. Hunte...
# Team        Boston CelticsBoston CelticsBoston CelticsBost...
# Number                                                   8079
# Position    PGSFSGSGPFPFPFCPGPGCPGSGSGCSGSGSGSGPGSGSGPGCPF...
# Age                                                     12311
# Height                                                 101236
# Salary                                           2159837111.0
# dtype: object

# %%
nba.mean()
# Out:
# C:\Users\Betul\AppData\Local\Temp/ipykernel_4788/3862783939.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   nba.mean()
# Number    1.767834e+01
# Age       2.693873e+01
# Height    2.215230e+02
# Salary    4.842684e+06
# dtype: float64

# %%
nba[["Team", "Age", "Height"]]
# Out:
#                Team  Age  Height
# 0    Boston Celtics   25     180
# 1    Boston Celtics   25     235
# 2    Boston Celtics   27     205
# 3    Boston Celtics   22     185
# 4    Boston Celtics   29     231
# ..              ...  ...     ...
# 452       Utah Jazz   20     234
# 453       Utah Jazz   26     203
# 454       Utah Jazz   24     179
# 455       Utah Jazz   26     256
# 456       Utah Jazz   26     231
#
# [457 rows x 3 columns]

# %%
nba["Sport"] = "Basketball"

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age  Height  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     235
# 2   John Holland  Boston Celtics      30       SG   27     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     231
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball
# 3      Georgia State  1148640.0  Basketball
# 4                NaN  5000000.0  Basketball

# %%
nba.insert(loc = 3, column="Weight", value= 80)

# %%
nba.head()
# Out:
#             Name            Team  Number  Weight Position  Age  Height  \
# 0  Avery Bradley  Boston Celtics       0      80       PG   25     180
# 1    Jae Crowder  Boston Celtics      99      80       SF   25     235
# 2   John Holland  Boston Celtics      30      80       SG   27     205
# 3    R.J. Hunter  Boston Celtics      28      80       SG   22     185
# 4  Jonas Jerebko  Boston Celtics       8      80       PF   29     231
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball
# 3      Georgia State  1148640.0  Basketball
# 4                NaN  5000000.0  Basketball

# %%
nba["Salary($)"] = round(nba["Salary"].div(11), 2)
nba.head()
# Out:
#             Name            Team  Number  Weight Position  Age  Height  \
# 0  Avery Bradley  Boston Celtics       0      80       PG   25     180
# 1    Jae Crowder  Boston Celtics      99      80       SF   25     235
# 2   John Holland  Boston Celtics      30      80       SG   27     205
# 3    R.J. Hunter  Boston Celtics      28      80       SG   22     185
# 4  Jonas Jerebko  Boston Celtics       8      80       PF   29     231
#
#              College     Salary       Sport  Salary($)
# 0              Texas  7730337.0  Basketball  702757.91
# 1          Marquette  6796117.0  Basketball  617828.82
# 2  Boston University        NaN  Basketball        NaN
# 3      Georgia State  1148640.0  Basketball  104421.82
# 4                NaN  5000000.0  Basketball  454545.45

# %%
nba.drop(columns = "Sport")
# Out:
#               Name            Team  Number  Weight Position  Age  Height  \
# 0    Avery Bradley  Boston Celtics       0      80       PG   25     180
# 1      Jae Crowder  Boston Celtics      99      80       SF   25     235
# 2     John Holland  Boston Celtics      30      80       SG   27     205
# 3      R.J. Hunter  Boston Celtics      28      80       SG   22     185
# 4    Jonas Jerebko  Boston Celtics       8      80       PF   29     231
# ..             ...             ...     ...     ...      ...  ...     ...
# 452     Trey Lyles       Utah Jazz      41      80       PF   20     234
# 453   Shelvin Mack       Utah Jazz       8      80       PG   26     203
# 454      Raul Neto       Utah Jazz      25      80       PG   24     179
# 455   Tibor Pleiss       Utah Jazz      21      80        C   26     256
# 456    Jeff Withey       Utah Jazz      24      80        C   26     231
#
#                College     Salary  Salary($)
# 0                Texas  7730337.0  702757.91
# ...

# %%
nba.head()
# Out:
#             Name            Team  Number  Weight Position  Age  Height  \
# 0  Avery Bradley  Boston Celtics       0      80       PG   25     180
# 1    Jae Crowder  Boston Celtics      99      80       SF   25     235
# 2   John Holland  Boston Celtics      30      80       SG   27     205
# 3    R.J. Hunter  Boston Celtics      28      80       SG   22     185
# 4  Jonas Jerebko  Boston Celtics       8      80       PF   29     231
#
#              College     Salary       Sport  Salary($)
# 0              Texas  7730337.0  Basketball  702757.91
# 1          Marquette  6796117.0  Basketball  617828.82
# 2  Boston University        NaN  Basketball        NaN
# 3      Georgia State  1148640.0  Basketball  104421.82
# 4                NaN  5000000.0  Basketball  454545.45

# %%
employee = pd.read_csv("employee.csv")

# %%
employee.head()
# Out:
#   First Name  Gender Start Date Last Login Time    Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993          12:42        NaN    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933.0    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590.0   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705.0    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004.0    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
nba.head()
# Out:
#             Name            Team  Number  Weight Position  Age  Height  \
# 0  Avery Bradley  Boston Celtics       0      80       PG   25     180
# 1    Jae Crowder  Boston Celtics      99      80       SF   25     235
# 2   John Holland  Boston Celtics      30      80       SG   27     205
# 3    R.J. Hunter  Boston Celtics      28      80       SG   22     185
# 4  Jonas Jerebko  Boston Celtics       8      80       PF   29     231
#
#              College     Salary       Sport  Salary($)
# 0              Texas  7730337.0  Basketball  702757.91
# 1          Marquette  6796117.0  Basketball  617828.82
# 2  Boston University        NaN  Basketball        NaN
# 3      Georgia State  1148640.0  Basketball  104421.82
# 4                NaN  5000000.0  Basketball  454545.45

# %%
nba["Position"].value_counts(ascending=True)
# Out:
# C      78
# SF     85
# PG     92
# PF    100
# SG    102
# Name: Position, dtype: int64

# %%
nba["College"].fillna(value = "No College Info")
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4        No College Info
#              ...
# 452             Kentucky
# 453               Butler
# 454      No College Info
# 455      No College Info
# 456               Kansas
# Name: College, Length: 457, dtype: object

# %%
nba["Salary"].fillna(method='ffill')
# Out:
# 0      7730337.0
# 1      6796117.0
# 2      6796117.0
# 3      1148640.0
# 4      5000000.0
#          ...
# 452    2239800.0
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# Name: Salary, Length: 457, dtype: float64

# %%
nba.head(7)
# Out:
#             Name            Team  Number  Weight Position  Age  Height  \
# 0  Avery Bradley  Boston Celtics       0      80       PG   25     180
# 1    Jae Crowder  Boston Celtics      99      80       SF   25     235
# 2   John Holland  Boston Celtics      30      80       SG   27     205
# 3    R.J. Hunter  Boston Celtics      28      80       SG   22     185
# 4  Jonas Jerebko  Boston Celtics       8      80       PF   29     231
# 5   Amir Johnson  Boston Celtics      90      80       PF   29     240
# 6  Jordan Mickey  Boston Celtics      55      80       PF   21     235
#
#              College      Salary       Sport   Salary($)
# 0              Texas   7730337.0  Basketball   702757.91
# 1          Marquette   6796117.0  Basketball   617828.82
# 2  Boston University         NaN  Basketball         NaN
# 3      Georgia State   1148640.0  Basketball   104421.82
# 4                NaN   5000000.0  Basketball   454545.45
# ...

# %%
nba["Position"] = nba["Position"].astype("category")

# %%
nba.sort_values(["Position", "Age", "Height"], ascending=[True, False, True], inplace=True)

# %%
nba["Position"].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba.head()
# Out:
#               Name                   Team  Number  Weight Position  Age  \
# 298     Tim Duncan      San Antonio Spurs      21      80        C   40
# 420  Nazr Mohammed  Oklahoma City Thunder      13      80        C   38
# 296    Matt Bonner      San Antonio Spurs      15      80        C   36
# 156      Pau Gasol          Chicago Bulls      16      80        C   35
# 297     Boris Diaw      San Antonio Spurs      33      80        C   34
#
#      Height      College     Salary       Sport  Salary($)
# 298     250  Wake Forest  5250000.0  Basketball  477272.73
# 420     250     Kentucky   222888.0  Basketball   20262.55
# 296     235      Florida   947276.0  Basketball   86116.00
# 156     250          NaN  7448760.0  Basketball  677160.00
# 297     250          NaN  7500000.0  Basketball  681818.18

# %%
maske1 = nba["Position"] == "C"
maske2 = nba["Age"] >=30
maske3 = nba["Position"].isin(["SG","PF","PG","SF"])

# %%
nba[maske3]
# Out:
#                         Name                    Team  Number  Weight Position  \
# 400            Kevin Garnett  Minnesota Timberwolves      21      80       PF
# 236            Dirk Nowitzki        Dallas Mavericks      41      80       PF
# 259           Chris Andersen       Memphis Grizzlies       7      80       PF
# 46               Elton Brand      Philadelphia 76ers      42      80       PF
# 343            Udonis Haslem              Miami Heat      40      80       PF
# ..                       ...                     ...     ...     ...      ...
# 357            Mario Hezonja           Orlando Magic      23      80       SG
# 18   Rondae Hollis-Jefferson           Brooklyn Nets      24      80       SG
# 13               James Young          Boston Celtics      13      80       SG
# 226            Rashad Vaughn         Milwaukee Bucks      20      80       SG
# 122             Devin Booker            Phoenix Suns       1      80       SG
#
# ...

# %%
nba_na = pd.read_csv("nba.csv")
nba_na.head(7)
# Out:
#             Name            Team  Number Position  Age  Height  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     235
# 2   John Holland  Boston Celtics      30       SG   27     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     231
# 5   Amir Johnson  Boston Celtics      90       PF   29     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21     235
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0
# 6                LSU   1170960.0

# %%
maske1 = nba_na["College"].isna()

# %%
nba_na[maske1]
# Out:
#                        Name             Team  Number Position  Age  Height  \
# 4             Jonas Jerebko   Boston Celtics       8       PF   29     231
# 5              Amir Johnson   Boston Celtics      90       PF   29     240
# 15         Bojan Bogdanovic    Brooklyn Nets      44       SG   27     216
# 20           Sergey Karasev    Brooklyn Nets      10       SG   22     208
# 32   Thanasis Antetokounmpo  New York Knicks      43       SF   23     205
# ..                      ...              ...     ...      ...  ...     ...
# 445              Dante Exum        Utah Jazz      11       PG   20     190
# 447             Rudy Gobert        Utah Jazz      27        C   23     245
# 450              Joe Ingles        Utah Jazz       2       SF   28     226
# 454               Raul Neto        Utah Jazz      25       PG   24     179
# 455            Tibor Pleiss        Utah Jazz      21        C   26     256
#
#     College      Salary
# 4       NaN   5000000.0
# ...

# %%
employee = pd.read_csv("employee.csv")
employee.head()
# Out:
#   First Name  Gender Start Date Last Login Time    Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993          12:42        NaN    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933.0    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590.0   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705.0    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004.0    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             999 non-null    float64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 62.6+ KB

# %%
employee["Gender"] = employee["Gender"].astype('category')

# %%
employee["Start Date"] = pd.to_datetime(employee["Start Date"], format='%m/%d/%Y')

# %%
employee.head()
# Out:
#   First Name  Gender Start Date Last Login Time    Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06          12:42        NaN    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933.0    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590.0   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705.0    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004.0    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
employee["Senior Management"] = employee["Senior Management"].astype('bool')

# %%
employee["Team"].fillna("No Team Info", inplace=True)

# %%
employee.set_index(keys="Start Date", inplace=True)

# %%
employee.set_index(keys="First Name", inplace=True)

# %%
employee.loc["Thomas", ["Start Date","Salary"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4788/2072313400.py in <module>
# ----> 1 employee.loc["Thomas", ["Start Date","Salary"]]
#
# ~\PycharmProjects\EgitimNotlari\venv\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\PycharmProjects\EgitimNotlari\venv\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# -> 1100             return self._getitem_lowerdim(tup)
#    1101
# ...

# %%
employee.iloc[100:120, 0:4]
# Out:
#              Gender Last Login Time    Salary  Bonus %
# First Name
# Melissa      Female         6:33 AM   48109.0   14.995
# Aaron          Male        10:20 AM   61602.0   11.849
# Jack           Male         5:51 AM  103902.0   12.159
# Phyllis      Female         9:30 PM  136984.0    8.932
# John           Male         7:01 AM   80740.0   19.305
# Kathy        Female         4:33 AM   91712.0    8.567
# Paul           Male         7:25 PM   42146.0    3.046
# Steven         Male        10:12 PM   68680.0   16.565
# Russell         NaN         7:57 AM  133980.0   12.396
# Christopher    Male        10:15 AM   37919.0   11.449
# Shirley      Female        10:39 PM  147113.0   16.135
# Bonnie       Female         3:12 PM   42153.0    8.454
# Willie         Male         6:21 AM   64363.0    4.023
# Tina         Female         7:16 AM  114767.0    3.711
# Ashley       Female        11:00 AM   58698.0    6.811
# Pamela       Female         6:51 AM   54585.0    4.166
# ...

# %%
employee.loc["Jerry", ["Gender", "Salary"]] = ["Female", 100000]

# %%
employee.rename(mapper = {"Team": "(Team,)"}, axis = 1, inplace=True)

# %%
employee.head(7)
# Out:
#             Gender Last Login Time    Salary  Bonus %  Senior Management  \
# First Name
# Douglas       Male          12:42        NaN    6.945               True
# Thomas        Male         6:53 AM   61933.0    4.170               True
# Maria       Female        11:17 AM  130590.0   11.858              False
# Jerry       Female         1:00 PM  100000.0    9.340               True
# Larry         Male         4:47 PM  101004.0    1.389               True
# Dennis        Male         1:35 AM  115163.0   10.125              False
# Ruby        Female         4:20 PM   65476.0   10.012               True
#
#                     (Team,)
# First Name
# Douglas           Marketing
# Thomas         No Team Info
# Maria               Finance
# Jerry               Finance
# Larry       Client Services
# Dennis                Legal
# Ruby                Product

# %%
employee.loc["Thomas", "Male"] = "Mr Thomas"

# %%
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Douglas to Albert
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             855 non-null    category
#  1   Last Login Time    1000 non-null   object
#  2   Salary             999 non-null    float64
#  3   Bonus %            1000 non-null   float64
#  4   Senior Management  1000 non-null   bool
#  5   (Team,)            1000 non-null   object
#  6   Male               7 non-null      object
# dtypes: bool(1), category(1), float64(2), object(3)
# memory usage: 81.2+ KB

# %%
employee.drop(columns = "(Thomas, Name)", axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4788/3144528933.py in <module>
# ----> 1 employee.drop(columns = "(Thomas, Name)", axis = 1)
#
# ~\PycharmProjects\EgitimNotlari\venv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\PycharmProjects\EgitimNotlari\venv\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
gender = employee.pop("Gender")

# %%
employee.head(5)

# %%
employee["Gender"] = gender

# %%
employee.head()

# %%
employee.sample(frac = 0.25)

# %%
employee.nsmallest(n=20, columns = "Salary")

# %%
def maasSiniflandirma(maas):
    if maas < 100000:
        return "Düşük Gelirli"
    else:
        return "Yüksek Gelirli"

# %%
employee["Salary"].apply(maasSiniflandirma)

# %%
def primhesaplama(calisan):
    maas = calisan["Salary"]
    bonus = calisan["Bonus %"]
    cinsiyet = calisan[]
    prim = maas * bonus / 100
    return prim

# %%
employee["Prim"] = employee.apply(primhesaplama, axis=1)

# %%
employee["Salary"].fillna(method="bfill", inplace=True)

# %%
employee.head()

# %%
employee

# %%
employee.loc["Jerry"]

# %%
employee.loc["Thomas"]
